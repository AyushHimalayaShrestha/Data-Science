# %% [markdown]
# # Mock_DataSet

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('mock_dataset.csv')
data
# Out:
#       ID                Name  Age         City  Salary  Department  \
# 0      1     Emily Velasquez   54     New York   72765   Marketing
# 1      2       Heather White   41      Houston   94297          HR
# 2      3       Yvonne Tucker   47  Los Angeles   92338   Marketing
# 3      4       William Velez   22      Chicago   59292          IT
# 4      5        Daniel Baker   22  Los Angeles   69785          HR
# ..   ...                 ...  ...          ...     ...         ...
# 195  196  Kristine Rasmussen   60      Phoenix   75280          IT
# 196  197     Julia Gutierrez   48  Los Angeles   68275     Finance
# 197  198     Victoria Wilson   23      Phoenix   65698          HR
# 198  199      Austin Johnson   37      Houston   36019  Operations
# 199  200      Perry Matthews   59     New York   67582     Finance
#
#     Joining Date    Status
# 0     2021-12-27    Active
# 1     2014-12-07  Resigned
# 2     2019-07-11    Active
# 3     2019-01-04    Active
# ...

# %%
data.describe(include='all')
# Out:
#                 ID          Name         Age         City        Salary  \
# count   200.000000           200  200.000000          200    200.000000
# unique         NaN           199         NaN            5           NaN
# top            NaN  Travis Smith         NaN  Los Angeles           NaN
# freq           NaN             2         NaN           53           NaN
# mean    100.500000           NaN   38.730000          NaN  63058.615000
# std      57.879185           NaN   11.926791          NaN  20430.024738
# min       1.000000           NaN   19.000000          NaN  30075.000000
# 25%      50.750000           NaN   28.000000          NaN  44099.250000
# 50%     100.500000           NaN   38.500000          NaN  62576.000000
# 75%     150.250000           NaN   49.000000          NaN  80340.750000
# max     200.000000           NaN   60.000000          NaN  99711.000000
#
#         Department Joining Date  Status
# count          200          200     200
# ...

# %%
data['Name'].str.len()
# Out:
# 0      15
# 1      13
# 2      13
# 3      13
# 4      12
#        ..
# 195    18
# 196    15
# 197    15
# 198    14
# 199    14
# Name: Name, Length: 200, dtype: int64

# %%
data['Name'].str.upper()
# Out:
# 0         EMILY VELASQUEZ
# 1           HEATHER WHITE
# 2           YVONNE TUCKER
# 3           WILLIAM VELEZ
# 4            DANIEL BAKER
#               ...
# 195    KRISTINE RASMUSSEN
# 196       JULIA GUTIERREZ
# 197       VICTORIA WILSON
# 198        AUSTIN JOHNSON
# 199        PERRY MATTHEWS
# Name: Name, Length: 200, dtype: object

# %%
data[data['Name'].str.len()==data['Name'].str.len().max()]
# Out:
#       ID                  Name  Age         City  Salary  Department  \
# 40    41  Alexandra Montgomery   28  Los Angeles   39990     Finance
# 121  122  Dr. Danielle Ballard   40  Los Angeles   45022  Operations
#
#     Joining Date    Status
# 40    2023-09-03  Resigned
# 121   2017-07-27    Active

# %%
data['Name'].str.split(',')
# Out:
# 0         [Emily Velasquez]
# 1           [Heather White]
# 2           [Yvonne Tucker]
# 3           [William Velez]
# 4            [Daniel Baker]
#                ...
# 195    [Kristine Rasmussen]
# 196       [Julia Gutierrez]
# 197       [Victoria Wilson]
# 198        [Austin Johnson]
# 199        [Perry Matthews]
# Name: Name, Length: 200, dtype: object

# %%
data['Name'].nunique()
# Out:
# 199

# %%
data[data['Name'].str.startswith('A')]
# Out:
#       ID                  Name  Age         City  Salary  Department  \
# 9     10            Adam Chung   25     New York   80361          IT
# 20    21        Alexander Rowe   27      Chicago   53177  Operations
# 25    26            Adam Tyler   55     New York   41344     Finance
# 40    41  Alexandra Montgomery   28  Los Angeles   39990     Finance
# 52    53         Andrew Palmer   45      Houston   30675     Finance
# 64    65        Aaron Mccarthy   36  Los Angeles   44282  Operations
# 65    66         Angela Thomas   41      Chicago   99711     Finance
# 85    86     Alexander Jackson   27      Chicago   75013   Marketing
# 89    90        Ann Snyder DDS   23     New York   42825     Finance
# 90    91          Angela Jones   35  Los Angeles   52152          HR
# 103  104              Amy Sims   21      Phoenix   54762          HR
# 106  107       April Patterson   38      Houston   34398          IT
# 107  108            Anne Mills   21     New York   38428          IT
# ...

# %%
data.shape
# Out:
# (200, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            200 non-null    int64
#  1   Name          200 non-null    object
#  2   Age           200 non-null    int64
#  3   City          200 non-null    object
#  4   Salary        200 non-null    int64
#  5   Department    200 non-null    object
#  6   Joining Date  200 non-null    object
#  7   Status        200 non-null    object
# dtypes: int64(3), object(5)
# memory usage: 12.6+ KB
