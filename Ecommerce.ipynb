# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ecommerce=pd.read_csv('Ecommerce Purchases')
ecommerce
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
ecommerce.sample()
# Out:
#                                                 Address    Lot AM or PM  \
# 2165  84362 Patel Islands\nEast Christopher, HI 9409...  70 Vu       AM
#
#                                            Browser Info     Company  \
# 2165  Mozilla/5.0 (Windows; U; Windows NT 6.0) Apple...  Porter-Day
#
#        Credit Card CC Exp Date  CC Security Code CC Provider  \
# 2165  501886678298       11/24                98     Voyager
#
#                        Email        Job     IP Address Language  \
# 2165  gordonamanda@yahoo.com  Dietitian  17.180.255.85       it
#
#       Purchase Price
# 2165           66.52

# %%
ecommerce.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
ecommerce.isnull().sum()
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %%
ecommerce.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %% [markdown]
# # Description
# - There are 14 columns and 10000 rows.
# - There are no null values.
# - There are 5068 PM and 4932 AM.
# - There are 623 type of jobs.
# - There are 8287 browser
# - There are 8653 Company.
# - There are 121 unique CC Exp Date.
# - There are 1758 unique CC Security Code.
# - IP Address is in string format

# %%
ecommerce.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
ecommerce['Address'].nunique()
# Out:
# 10000

# %%
ecommerce['Lot'].nunique()
# Out:
# 9822

# %%
ecommerce[ecommerce['Lot'].duplicated()]
# Out:
#                                                 Address    Lot AM or PM  \
# 453   5716 Luis Club Suite 243\nLake Emilyborough, I...  62 Ac       AM
# 925   16191 Adrian Harbor\nSouth Hollyburgh, ND 2265...  73 uU       PM
# 1076     195 Kevin Pine Apt. 435\nAmandamouth, ID 94650  82 ga       PM
# 1096             63572 Bailey Fork\nPort Lori, AS 39844  15 ah       AM
# 1193        693 Seth Highway\nCharleston, FM 30563-4072  75 vm       PM
# ...                                                 ...    ...      ...
# 9836  99698 Franco Row Suite 859\nWest Krystalboroug...  01 PA       PM
# 9857              Unit 5206 Box 4943\nDPO AA 69262-6645  79 eA       PM
# 9866        25024 Shane Unions\nRandyton, HI 61446-9058  95 JP       AM
# 9924      3996 Cooper Mission\nAguilarborough, AR 99039  36 vm       PM
# 9959      21298 Jacob Avenue\nNew Michaelland, AZ 17444  96 hh       PM
#
#                                            Browser Info  \
# ...

# %%
ecommerce[ecommerce['Lot'].duplicated(keep=False)]
# Out:
#                                                 Address    Lot AM or PM  \
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 24                Unit 3046 Box 3197\nDPO AE 61496-4172  62 Ac       AM
# 100        9980 Ramirez Grove\nSmithview, AZ 13342-4996  34 bB       AM
# 260      291 Jon Views Suite 503\nYufort, ND 78877-6409  77 bc       PM
# 275       3042 Kenneth Route\nPort Leroy, TN 58026-8936  57 dc       PM
# ...                                                 ...    ...      ...
# 9836  99698 Franco Row Suite 859\nWest Krystalboroug...  01 PA       PM
# 9857              Unit 5206 Box 4943\nDPO AA 69262-6645  79 eA       PM
# 9866        25024 Shane Unions\nRandyton, HI 61446-9058  95 JP       AM
# 9924      3996 Cooper Mission\nAguilarborough, AR 99039  36 vm       PM
# 9959      21298 Jacob Avenue\nNew Michaelland, AZ 17444  96 hh       PM
#
#                                            Browser Info  \
# ...

# %%
ecommerce['AM or PM'].value_counts()
# Out:
# AM or PM
# PM    5068
# AM    4932
# Name: count, dtype: int64

# %%
sns.countplot(x=ecommerce['AM or PM'])
# Out:
# <Axes: xlabel='AM or PM', ylabel='count'>

# %%
ecommerce['Browser Info'].nunique()
# Out:
# 8287

# %%
ecommerce[ecommerce['Browser Info'].duplicated().sort_values()]
# Out:
# /var/folders/j7/4zx6knds3q1dm6hxjrs0kpfr0000gn/T/ipykernel_19608/1202951788.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ecommerce[ecommerce['Browser Info'].duplicated().sort_values()]
#                                                 Address    Lot AM or PM  \
# 138   6885 Schroeder Terrace Suite 272\nPort Andrewb...  84 lB       PM
# 183   0024 Smith Tunnel Suite 760\nPort Leeton, CO 8...  52 Eg       PM
# 278   948 Dennis Grove Apt. 933\nEast Marilyn, PA 44...  68 Po       AM
# 282                    PSC 3302, Box 3423\nAPO AA 05157  24 Eu       AM
# 311   26924 Robert Garden Apt. 754\nBethhaven, MT 50708  79 eA       AM
# ...                                                 ...    ...      ...
# 9983              PSC 5678, Box 4503\nAPO AP 94998-5546  79 cd       AM
# 9988      0154 Green Forest\nNew Timothy, IL 33670-4620  11 MC       AM
# 9989         5674 Cruz Trace\nNew Shelby, KY 51047-5469  12 Kf       AM
# ...

# %%
ax=sns.countplot(x=ecommerce['AM or PM'])
for container in ax.containers:
    ax.bar_label(container, fmt='%.0f', label_type='edge', padding=3)
plt.show()

# %%
ecommerce['Company'].nunique()
# Out:
# 8653

# %%
ecommerce['Email'].nunique()
# Out:
# 9954

# %%
ecommerce[ecommerce['Email'].duplicated(keep=False)]
# Out:
#                                                 Address    Lot AM or PM  \
# 5     7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 91            874 Tanner Islands\nJosephhaven, ND 47343  64 Aj       AM
# 223   7965 Gardner Trail\nWest Robertport, MT 38876-...  15 Ee       AM
# 431    728 Lori Via Apt. 120\nDarylshire, HI 75881-1046  93 nZ       AM
# 433       9667 Michael Road\nSouth Tylershire, UT 36934  10 Mo       AM
# ...                                                 ...    ...      ...
# 9174                   Unit 6545 Box 2090\nDPO AA 05290  65 RJ       PM
# 9267  9277 Caldwell Ville Apt. 884\nGabrielhaven, AL...  76 kq       PM
# 9456    2372 Brian Summit\nNew Stephaniehaven, GA 66547  67 zZ       PM
# 9520  743 Hatfield Port Apt. 784\nPort Claytonville,...  27 UU       AM
# 9678            319 Kyle Causeway\nWest Stacy, MO 47877  34 QI       AM
#
#                                            Browser Info  \
# ...

# %%
ecommerce['Credit Card'].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: Credit Card, Length: 10000, dtype: bool

# %%
ecommerce['Credit Card'].isnull().sum()
# Out:
# 0

# %%
ecommerce['Credit Card'].nunique()
# Out:
# 10000

# %%
ecommerce[ecommerce['CC Exp Date'].duplicated()]
# Out:
#                                                 Address    Lot AM or PM  \
# 19                  125 Hall Summit\nBoothton, IL 41721  99 CU       PM
# 29    30755 Joshua Plaza Apt. 567\nWest Susanton, FM...  93 OP       PM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# 40    821 Adams Courts Apt. 568\nNorth Nicole, MS 03...  35 gn       AM
# 42        605 Dillon Parks Apt. 900\nSarafort, WV 87894  40 cz       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
ecommerce['CC Exp Date'].nunique()
# Out:
# 121

# %%
ecommerce['CC Security Code'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: CC Security Code, Length: 10000, dtype: bool

# %%
ecommerce['CC Security Code'].duplicated().sum()
# Out:
# 8242

# %%
ecommerce['CC Security Code'].nunique()
# Out:
# 1758

# %%
ecommerce[ecommerce['Email'].duplicated(keep=False)].sort_values(by='Email')
# Out:
#                                                 Address    Lot AM or PM  \
# 7925           3856 Jessica Corner\nBrianview, OH 30437  22 rd       PM
# 433       9667 Michael Road\nSouth Tylershire, UT 36934  10 Mo       AM
# 3679  221 Kane Branch Apt. 484\nMelissamouth, NE 613...  40 vk       PM
# 8561                   PSC 5060, Box 5337\nAPO AA 78010  36 IN       AM
# 5300  63914 Valdez Street Suite 470\nNorth Brittanym...  15 JC       AM
# ...                                                 ...    ...      ...
# 3119   6719 Brown Cove\nSouth Teresatown, VI 96146-5186  20 Uo       PM
# 6694  38516 Kemp Knoll Suite 387\nWangstad, VA 35691...  65 Fu       AM
# 5     7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 1913                      USNS Ellis\nFPO AA 84124-1746  13 Tk       PM
# 2585  2626 Stokes Union Suite 410\nNorth Larryhaven,...  89 sV       PM
#
#                                            Browser Info  \
# ...

# %%
ecommerce['CC Exp Date'].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995     True
# 9996     True
# 9997     True
# 9998     True
# 9999     True
# Name: CC Exp Date, Length: 10000, dtype: bool

# %%
ecommerce['CC Provider'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: CC Provider, Length: 10000, dtype: bool

# %%
ecommerce['Job'].value_counts()
# Out:
# Job
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
#                                  ..
# Prison officer                    7
# Editor, film/video                6
# Actuary                           6
# Information systems manager       5
# Investment analyst                5
# Name: count, Length: 623, dtype: int64

# %%
ecommerce['Job'].nunique()
# Out:
# 623

# %%
ecommerce['IP Address'].nunique()
# Out:
# 10000

# %%
ecommerce['Language'].nunique()
# Out:
# 9

# %%
ecommerce['Language'].value_counts().plot(kind='pie',autopct='%0.01f%%')
# Out:
# <Axes: ylabel='count'>

# %%
ax=sns.countplot(x=ecommerce['Language'])
for container in ax.containers:
    ax.bar_label(container, fmt='%.01f', label_type='edge', padding=3)
plt.show()

# %%
ecommerce['Purchase Price'].describe()
# Out:
# count    10000.000000
# mean        50.347302
# std         29.015836
# min          0.000000
# 25%         25.150000
# 50%         50.505000
# 75%         75.770000
# max         99.990000
# Name: Purchase Price, dtype: float64

# %%
ecommerce['Purchase Price'].skew()
# Out:
# -0.008915427812629589

# %%
sns.kdeplot(x=ecommerce['Purchase Price'])
# Out:
# <Axes: xlabel='Purchase Price', ylabel='Density'>

# %%
ecommerce['CC Provider'].nunique()
# Out:
# 10

# %%
ecommerce['CC Provider'].value_counts()
# Out:
# CC Provider
# JCB 16 digit                   1716
# VISA 16 digit                  1715
# JCB 15 digit                    868
# American Express                849
# Maestro                         846
# Voyager                         829
# Discover                        817
# Mastercard                      816
# VISA 13 digit                   777
# Diners Club / Carte Blanche     767
# Name: count, dtype: int64

# %%
sns.boxplot(x=ecommerce['Purchase Price'])
# Out:
# <Axes: xlabel='Purchase Price'>

# %%
ecommerce['Purchase Price'].describe()
# Out:
# count    10000.000000
# mean        50.347302
# std         29.015836
# min          0.000000
# 25%         25.150000
# 50%         50.505000
# 75%         75.770000
# max         99.990000
# Name: Purchase Price, dtype: float64

# %%
ecommerce[ecommerce['Purchase Price'].min()== ecommerce['Purchase Price']]
# Out:
#                                                 Address    Lot AM or PM  \
# 2876  332 Jones Parkways\nEast Katherineville, GA 64230  39 GT       AM
# 5487     465 Mallory Ways\nNorth Rebecca, RI 82734-1160  93 OH       PM
#
#                                            Browser Info  \
# 2876  Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10_6_9...
# 5487  Mozilla/5.0 (X11; Linux i686; rv:1.9.6.20) Gec...
#
#                     Company       Credit Card CC Exp Date  CC Security Code  \
# 2876  Lyons, Diaz and Clark  4204500444841766       01/18                38
# 5487         Flynn and Sons    30469912089738       09/23               236
#
#         CC Provider                 Email                   Job  \
# 2876  VISA 16 digit  jennifer11@baker.com  Biomedical scientist
# 5487       Discover   mjohnson@austin.org         Stage manager
#
#           IP Address Language  Purchase Price
# 2876  223.47.177.174       it             0.0
# 5487     43.99.56.59       zh             0.0

# %%
ecommerce[ecommerce['Purchase Price'].max()==ecommerce['Purchase Price']]
# Out:
#                                         Address    Lot AM or PM  \
# 2092  63773 Shelton Greens\nAshleyton, MA 00493  56 lu       AM
# 7807      PSC 6177, Box 1004\nAPO AA 57143-1269  64 Nf       AM
#
#                                            Browser Info  \
# 2092  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 7807  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_5_4)...
#
#                         Company     Credit Card CC Exp Date  CC Security Code  \
# 2092                Pitts Group   4292741269160       06/18               824
# 7807  Porter, Johnson and Pratt  30109394842259       11/25               918
#
#         CC Provider                     Email                     Job  \
# 2092        Maestro  heatherwoodard@lloyd.com  Surveyor, hydrographic
# 7807  VISA 16 digit         kelli72@gmail.com     Surveyor, insurance
#
#            IP Address Language  Purchase Price
# 2092  172.197.216.229       el           99.99
# 7807     89.51.92.242       de           99.99

# %%
ecommerce[ecommerce['Purchase Price'].max()==ecommerce['Purchase Price']]
# Out:
#                                         Address    Lot AM or PM  \
# 2092  63773 Shelton Greens\nAshleyton, MA 00493  56 lu       AM
# 7807      PSC 6177, Box 1004\nAPO AA 57143-1269  64 Nf       AM
#
#                                            Browser Info  \
# 2092  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 7807  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_5_4)...
#
#                         Company     Credit Card CC Exp Date  CC Security Code  \
# 2092                Pitts Group   4292741269160       06/18               824
# 7807  Porter, Johnson and Pratt  30109394842259       11/25               918
#
#         CC Provider                     Email                     Job  \
# 2092        Maestro  heatherwoodard@lloyd.com  Surveyor, hydrographic
# 7807  VISA 16 digit         kelli72@gmail.com     Surveyor, insurance
#
#            IP Address Language  Purchase Price
# 2092  172.197.216.229       el           99.99
# 7807     89.51.92.242       de           99.99

# %%
ecommerce['Language'].value_counts()['fr']
French_Speaker=ecommerce['Language'].value_counts()['fr']
print('French Speaker : ',French_Speaker)
# Out:
# French Speaker :  1097

# %%
ecommerce[ecommerce['Job'].str.contains('engineer', case=False)]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 50      41159 Michael Centers\nAdamsfort, RI 37108-6674  46 Ce       PM
# 55    27635 Maureen Bypass Apt. 883\nSandraview, SD ...  59 LJ       AM
# 60    7126 Katherine Squares\nPerkinsview, CO 97299-...  63 qu       AM
# ...                                                 ...    ...      ...
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9952            9991 Vaughn Hills\nRacheltown, PA 55409  36 KC       PM
# 9970              0060 Keith Stream\nWestport, CO 47097  11 nt       PM
# 9977  02182 Keith Expressway\nEast Shannon, CT 20578...  34 RL       AM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
#
#                                            Browser Info  \
# ...

# %%
ecommerce[ecommerce['IP Address']=='132.207.160.22'][['Email','IP Address']]
# Out:
#                             Email      IP Address
# 2  amymiller@morales-harrison.com  132.207.160.22

# %%
ecommerce[(ecommerce['CC Provider'].str.contains('mastercard', case=False))&(ecommerce['Purchase Price']>50)]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 18    461 Christopher Square\nWest Michaelchester, C...  17 SB       PM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# 35    93392 Webb Gardens Apt. 220\nLaurabury, AR 999...  37 om       AM
# 90          431 Bowen Lights\nFergusonborough, MH 01362  31 tG       AM
# ...                                                 ...    ...      ...
# 9941           43757 Brown Lodge\nValerieberg, PR 88518  68 DG       AM
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9954  051 Samantha Wells Apt. 328\nScottborough, OR ...  11 vG       AM
# 9981  087 Larson Roads Apt. 587\nRicestad, WI 98077-...  95 Kw       AM
# 9987     2754 Klein Mission\nJohnsonview, PA 64925-9624  65 Fg       PM
#
#                                            Browser Info  \
# ...

# %%
ecommerce[(ecommerce['CC Provider'].str.contains('mastercard', case=False))&(ecommerce['Purchase Price']>50)].shape[0]
# Out:
# 405

# %%
ecommerce[ecommerce['Credit Card']==4664825258997302]['Email']
# Out:
# 9992    bberry@wright.net
# Name: Email, dtype: object

# %%
ecommerce['AM or PM'].value_counts()
# Out:
# AM or PM
# PM    5068
# AM    4932
# Name: count, dtype: int64

# %%
PM=ecommerce['AM or PM'].value_counts()['PM']
PM
# Out:
# 5068

# %%
AM=ecommerce['AM or PM'].value_counts()['AM']
AM
# Out:
# 4932

# %%
ecommerce[ecommerce['CC Exp Date'].str.split('/').str.get(1)=='20']
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 19                  125 Hall Summit\nBoothton, IL 41721  99 CU       PM
# 32                     Unit 3628 Box 6778\nDPO AE 72362  39 Qm       PM
# 36    9374 Skinner Common Apt. 254\nChristopherfort,...  80 Fq       PM
# 38    9671 Riley Drives Apt. 746\nPort Davidtown, TN...  15 vj       AM
# ...                                                 ...    ...      ...
# 9883        751 Petersen Groves\nLake Rebecca, NM 55875  61 tE       PM
# 9901      908 Norman Burgs\nPhillipsberg, VT 92023-9956  90 Ng       PM
# 9911  44320 Gray Centers Suite 325\nJenniferfurt, OK...  19 Bf       PM
# 9957             73556 Chase Pine\nBrucemouth, MP 73473  25 rU       PM
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
#
#                                            Browser Info  \
# ...

# %%
ecommerce[ecommerce['CC Exp Date'].str.split('/').str.get(1)=='20'].shape[0]
# Out:
# 988

# %%
ecommerce['Email'].str.split('@')
# Out:
# 0                    [pdunlap, yahoo.com]
# 1                   [anthony41, reed.com]
# 2       [amymiller, morales-harrison.com]
# 3          [brent16, olson-robinson.info]
# 4          [christopherwright, gmail.com]
#                       ...
# 9995            [iscott, wade-garner.com]
# 9996                [mary85, hotmail.com]
# 9997                 [tyler16, gmail.com]
# 9998           [elizabethmoore, reid.net]
# 9999             [rachelford, vaughn.com]
# Name: Email, Length: 10000, dtype: object

# %%
ecommerce['Email'].str.split('@').str.get(1).value_counts().head()
# Out:
# Email
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: count, dtype: int64

# %%
ecommerce['Browser Info'].str.split('/').str.get(0)
# Out:
# 0         Opera
# 1         Opera
# 2       Mozilla
# 3       Mozilla
# 4         Opera
#          ...
# 9995    Mozilla
# 9996    Mozilla
# 9997    Mozilla
# 9998    Mozilla
# 9999    Mozilla
# Name: Browser Info, Length: 10000, dtype: object

# %%
ecommerce['Browser Info'].str.split('/').str.get(0).value_counts()
# Out:
# Browser Info
# Mozilla    7924
# Opera      2076
# Name: count, dtype: int64

# %%
ecommerce['Browser Info'].str.split('/').str.get(0).value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Browser Info'>

# %%
totalPurchase=ecommerce.groupby(by='CC Provider')[['Purchase Price']].sum().reset_index()
totalPurchase
# Out:
#                    CC Provider  Purchase Price
# 0             American Express        42865.52
# 1  Diners Club / Carte Blanche        37378.39
# 2                     Discover        42208.13
# 3                 JCB 15 digit        44376.60
# 4                 JCB 16 digit        84597.33
# 5                      Maestro        42620.78
# 6                   Mastercard        40835.10
# 7                VISA 13 digit        39976.54
# 8                VISA 16 digit        85528.86
# 9                      Voyager        43085.77

# %%
plt.figure(figsize=(15,5))
ax=sns.barplot(ecommerce, x='CC Provider', y='Purchase Price')
for container in ax.containers:
    ax.bar_label(container,padding=2)
plt.xticks(rotation=70)
plt.show()

# %%
plt.figure(figsize=(15,5))
ax=sns.barplot(totalPurchase, x='CC Provider', y='Purchase Price')
for container in ax.containers:
    ax.bar_label(container,padding=2, label_type='center')
plt.xticks(rotation=70)
plt.show()

# %%
ecommerce.groupby('AM or PM')['Purchase Price'].mean()
# Out:
# AM or PM
# AM    50.186511
# PM    50.503779
# Name: Purchase Price, dtype: float64

# %%
ecommerce[(ecommerce['CC Provider']=='JCB 16 digit') & (ecommerce['CC Exp Date'].str.split('/').str.get(1) =='24')]['Purchase Price'].sum()
# Out:
# 8987.74

# %%
ecommerce.groupby('CC Provider')['AM or PM'].value_counts()
# Out:
# CC Provider                  AM or PM
# American Express             AM          428
#                              PM          421
# Diners Club / Carte Blanche  PM          385
#                              AM          382
# Discover                     PM          428
#                              AM          389
# JCB 15 digit                 PM          449
#                              AM          419
# JCB 16 digit                 AM          871
#                              PM          845
# Maestro                      PM          454
#                              AM          392
# Mastercard                   PM          438
#                              AM          378
# VISA 13 digit                AM          395
#                              PM          382
# VISA 16 digit                PM          865
#                              AM          850
# Voyager                      AM          428
#                              PM          401
# ...

# %%
ecommerce.groupby(['CC Provider'])[['AM or PM']].value_counts().reset_index()
# Out:
#                     CC Provider AM or PM  count
# 0              American Express       AM    428
# 1              American Express       PM    421
# 2   Diners Club / Carte Blanche       PM    385
# 3   Diners Club / Carte Blanche       AM    382
# 4                      Discover       PM    428
# 5                      Discover       AM    389
# 6                  JCB 15 digit       PM    449
# 7                  JCB 15 digit       AM    419
# 8                  JCB 16 digit       AM    871
# 9                  JCB 16 digit       PM    845
# 10                      Maestro       PM    454
# 11                      Maestro       AM    392
# 12                   Mastercard       PM    438
# 13                   Mastercard       AM    378
# 14                VISA 13 digit       AM    395
# 15                VISA 13 digit       PM    382
# 16                VISA 16 digit       PM    865
# 17                VISA 16 digit       AM    850
# 18                      Voyager       AM    428
# ...

# %%
ecommerce.pivot_table(index='CC Provider', columns='AM or PM', aggfunc='count')
# Out:
#                             Address      Browser Info      CC Exp Date       \
# AM or PM                         AM   PM           AM   PM          AM   PM
# CC Provider
# American Express                428  421          428  421         428  421
# Diners Club / Carte Blanche     382  385          382  385         382  385
# Discover                        389  428          389  428         389  428
# JCB 15 digit                    419  449          419  449         419  449
# JCB 16 digit                    871  845          871  845         871  845
# Maestro                         392  454          392  454         392  454
# Mastercard                      378  438          378  438         378  438
# VISA 13 digit                   395  382          395  382         395  382
# VISA 16 digit                   850  865          850  865         850  865
# Voyager                         428  401          428  401         428  401
#
# ...

# %%
pd.crosstab(ecommerce['CC Provider'],ecommerce['AM or PM'], margins=True, margins_name='Total')
# Out:
# AM or PM                       AM    PM  Total
# CC Provider
# American Express              428   421    849
# Diners Club / Carte Blanche   382   385    767
# Discover                      389   428    817
# JCB 15 digit                  419   449    868
# JCB 16 digit                  871   845   1716
# Maestro                       392   454    846
# Mastercard                    378   438    816
# VISA 13 digit                 395   382    777
# VISA 16 digit                 850   865   1715
# Voyager                       428   401    829
# Total                        4932  5068  10000

# %%
plt.figure(figsize=(15,5))
ax=sns.countplot(ecommerce, x='CC Provider',hue='AM or PM')
for container in ax.containers:
    ax.bar_label(container)
plt.xticks(rotation=70)    
plt.title('No. of People Purchase by CC Provider')
plt.ylabel('No.of People')
plt.show()
