# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
expense = pd.read_csv('expense_data.csv')
expense
# Out:
#                  Date               Account        Category  Subcategory  \
# 0      3/2/2022 10:11  CUB - online payment            Food          NaN
# 1      3/2/2022 10:11  CUB - online payment           Other          NaN
# 2      3/1/2022 19:50  CUB - online payment            Food          NaN
# 3      3/1/2022 18:56  CUB - online payment  Transportation          NaN
# 4      3/1/2022 18:22  CUB - online payment            Food          NaN
# ..                ...                   ...             ...          ...
# 272  11/22/2021 14:16  CUB - online payment            Food          NaN
# 273  11/22/2021 14:16  CUB - online payment            Food          NaN
# 274  11/21/2021 17:07  CUB - online payment  Transportation          NaN
# 275  11/21/2021 15:50  CUB - online payment            Food          NaN
# 276  11/21/2021 13:30  CUB - online payment           Other          NaN
#
#                    Note     NRS Income/Expense  Note.1  Amount Currency  \
# ...

# %%
expense.dropna(axis=1, inplace=True)

# %%
expense.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            277 non-null    object
#  1   Account         277 non-null    object
#  2   Category        277 non-null    object
#  3   NRS             277 non-null    float64
#  4   Income/Expense  277 non-null    object
#  5   Amount          277 non-null    float64
#  6   Currency        277 non-null    object
#  7   Account.1       277 non-null    float64
# dtypes: float64(3), object(5)
# memory usage: 17.4+ KB

# %%
expense[(expense['Amount']== expense['Account.1'])]
# Out:
#                  Date               Account        Category     NRS  \
# 0      3/2/2022 10:11  CUB - online payment            Food    50.0
# 1      3/2/2022 10:11  CUB - online payment           Other   300.0
# 2      3/1/2022 19:50  CUB - online payment            Food    78.0
# 3      3/1/2022 18:56  CUB - online payment  Transportation    30.0
# 4      3/1/2022 18:22  CUB - online payment            Food    67.0
# ..                ...                   ...             ...     ...
# 272  11/22/2021 14:16  CUB - online payment            Food    90.0
# 273  11/22/2021 14:16  CUB - online payment            Food    97.0
# 274  11/21/2021 17:07  CUB - online payment  Transportation   130.0
# 275  11/21/2021 15:50  CUB - online payment            Food   875.0
# 276  11/21/2021 13:30  CUB - online payment           Other  2000.0
#
#     Income/Expense  Amount Currency  Account.1
# 0          Expense    50.0      NRS       50.0
# 1          Expense   300.0      NRS      300.0
# ...

# %%
expense[(expense['Amount']==expense['NRS'])]
# Out:
#                  Date               Account        Category     NRS  \
# 0      3/2/2022 10:11  CUB - online payment            Food    50.0
# 1      3/2/2022 10:11  CUB - online payment           Other   300.0
# 2      3/1/2022 19:50  CUB - online payment            Food    78.0
# 3      3/1/2022 18:56  CUB - online payment  Transportation    30.0
# 4      3/1/2022 18:22  CUB - online payment            Food    67.0
# ..                ...                   ...             ...     ...
# 272  11/22/2021 14:16  CUB - online payment            Food    90.0
# 273  11/22/2021 14:16  CUB - online payment            Food    97.0
# 274  11/21/2021 17:07  CUB - online payment  Transportation   130.0
# 275  11/21/2021 15:50  CUB - online payment            Food   875.0
# 276  11/21/2021 13:30  CUB - online payment           Other  2000.0
#
#     Income/Expense  Amount Currency  Account.1
# 0          Expense    50.0      NRS       50.0
# 1          Expense   300.0      NRS      300.0
# ...

# %%
expense.drop(columns=['Amount','Currency','Account.1'],inplace=True)

# %%
expense.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            277 non-null    object
#  1   Account         277 non-null    object
#  2   Category        277 non-null    object
#  3   NRS             277 non-null    float64
#  4   Income/Expense  277 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 10.9+ KB

# %%
expense
# Out:
#                  Date               Account        Category     NRS  \
# 0      3/2/2022 10:11  CUB - online payment            Food    50.0
# 1      3/2/2022 10:11  CUB - online payment           Other   300.0
# 2      3/1/2022 19:50  CUB - online payment            Food    78.0
# 3      3/1/2022 18:56  CUB - online payment  Transportation    30.0
# 4      3/1/2022 18:22  CUB - online payment            Food    67.0
# ..                ...                   ...             ...     ...
# 272  11/22/2021 14:16  CUB - online payment            Food    90.0
# 273  11/22/2021 14:16  CUB - online payment            Food    97.0
# 274  11/21/2021 17:07  CUB - online payment  Transportation   130.0
# 275  11/21/2021 15:50  CUB - online payment            Food   875.0
# 276  11/21/2021 13:30  CUB - online payment           Other  2000.0
#
#     Income/Expense
# 0          Expense
# 1          Expense
# 2          Expense
# 3          Expense
# 4          Expense
# ..             ...
# ...

# %%
expense['Income/Expense'].value_counts()
# Out:
# Income/Expense
# Expense    231
# Income      46
# Name: count, dtype: int64

# %%
expense['Date']=pd.to_datetime(expense['Date'])

# %%
expense['Year']=pd.to_datetime(expense['Date']).dt.year

# %%
expense['Month']=pd.to_datetime(expense['Date']).dt.month_name()

# %%
expense['Day']=pd.to_datetime(expense['Date']).dt.day

# %%
expense['Income/Expense'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
expense
# Out:
#                    Date               Account        Category     NRS  \
# 0   2022-03-02 10:11:00  CUB - online payment            Food    50.0
# 1   2022-03-02 10:11:00  CUB - online payment           Other   300.0
# 2   2022-03-01 19:50:00  CUB - online payment            Food    78.0
# 3   2022-03-01 18:56:00  CUB - online payment  Transportation    30.0
# 4   2022-03-01 18:22:00  CUB - online payment            Food    67.0
# ..                  ...                   ...             ...     ...
# 272 2021-11-22 14:16:00  CUB - online payment            Food    90.0
# 273 2021-11-22 14:16:00  CUB - online payment            Food    97.0
# 274 2021-11-21 17:07:00  CUB - online payment  Transportation   130.0
# 275 2021-11-21 15:50:00  CUB - online payment            Food   875.0
# 276 2021-11-21 13:30:00  CUB - online payment           Other  2000.0
#
#     Income/Expense  Year     Month  Day
# 0          Expense  2022     March    2
# 1          Expense  2022     March    2
# ...

# %%
exp=expense[expense['Income/Expense']=='Expense']
exp
# Out:
#                    Date               Account        Category    NRS  \
# 0   2022-03-02 10:11:00  CUB - online payment            Food   50.0
# 1   2022-03-02 10:11:00  CUB - online payment           Other  300.0
# 2   2022-03-01 19:50:00  CUB - online payment            Food   78.0
# 3   2022-03-01 18:56:00  CUB - online payment  Transportation   30.0
# 4   2022-03-01 18:22:00  CUB - online payment            Food   67.0
# ..                  ...                   ...             ...    ...
# 271 2021-11-23 22:53:00  CUB - online payment            Food  179.0
# 272 2021-11-22 14:16:00  CUB - online payment            Food   90.0
# 273 2021-11-22 14:16:00  CUB - online payment            Food   97.0
# 274 2021-11-21 17:07:00  CUB - online payment  Transportation  130.0
# 275 2021-11-21 15:50:00  CUB - online payment            Food  875.0
#
#     Income/Expense  Year     Month  Day
# 0          Expense  2022     March    2
# 1          Expense  2022     March    2
# ...

# %%
expByMonth=exp.groupby(['Year','Month'])[['NRS']].sum()
expByMonth
# Out:
#                     NRS
# Year Month
# 2021 December  16334.44
#      November   3620.40
# 2022 February  17864.65
#      January   20679.51
#      March       525.00
