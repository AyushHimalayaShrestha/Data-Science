# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
playstore=pd.read_csv('googleplaystore.csv.xls')
playstore
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
playstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# # Description
# - There are 9660 unique values in App.
# - There are 34 unique rows in Category.
# - There are 1474 null values in Rating.
# - There are missing values in most of the columns.

# %%
playstore['App'].duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# 10840    False
# Name: App, Length: 10841, dtype: bool

# %%
playstore['App'].nunique()
# Out:
# 9660

# %%
playstore.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
playstore['App'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# 10840    False
# Name: App, Length: 10841, dtype: bool

# %%
playstore['Category'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# 10840    False
# Name: Category, Length: 10841, dtype: bool

# %%
playstore['Category'].nunique()
# Out:
# 34

# %%
playstore['Rating'].isnull().sum()
# Out:
# 1474

# %%
playstore[playstore['Type'].isnull()]
# Out:
#                             App Category  Rating Reviews                Size  \
# 9148  Command & Conquer: Rivals   FAMILY     NaN       0  Varies with device
#
#      Installs Type Price Content Rating    Genres   Last Updated  \
# 9148        0  NaN     0   Everyone 10+  Strategy  June 28, 2018
#
#              Current Ver         Android Ver
# 9148  Varies with device  Varies with device

# %%
playstore['Rating'].describe()
# Out:
# count    9367.000000
# mean        4.193338
# std         0.537431
# min         1.000000
# 25%         4.000000
# 50%         4.300000
# 75%         4.500000
# max        19.000000
# Name: Rating, dtype: float64

# %%
playstore[playstore['Rating']==19]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
playstore.loc[[10472]]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
playstore.drop(10472, inplace=True)

# %%
playstore
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
playstore.isnull().sum()/len(playstore)*100
# Out:
# App                0.000000
# Category           0.000000
# Rating            13.597786
# Reviews            0.000000
# Size               0.000000
# Installs           0.000000
# Type               0.009225
# Price              0.000000
# Content Rating     0.000000
# Genres             0.000000
# Last Updated       0.000000
# Current Ver        0.073801
# Android Ver        0.018450
# dtype: float64

# %%
playstore[(playstore['Rating'].isnull())& (playstore['Type']=='Free')]
# Out:
#                                        App             Category  Rating  \
# 23                  Mcqueen Coloring pages       ART_AND_DESIGN     NaN
# 113              Wrinkles and rejuvenation               BEAUTY     NaN
# 123                 Manicure - nail design               BEAUTY     NaN
# 126           Skin Care and Natural Beauty               BEAUTY     NaN
# 129    Secrets of beauty, youth and health               BEAUTY     NaN
# ...                                    ...                  ...     ...
# 10824                            Cardio-FR              MEDICAL     NaN
# 10825                   Naruto & Boruto FR               SOCIAL     NaN
# 10831             payermonstationnement.fr  MAPS_AND_NAVIGATION     NaN
# 10835                             FR Forms             BUSINESS     NaN
# 10838               Parkinson Exercices FR              MEDICAL     NaN
#
#       Reviews  Size  Installs  Type Price Content Rating  \
# ...

# %%
playstore[playstore['Rating'].isnull()]
# Out:
#                                        App             Category  Rating  \
# 23                  Mcqueen Coloring pages       ART_AND_DESIGN     NaN
# 113              Wrinkles and rejuvenation               BEAUTY     NaN
# 123                 Manicure - nail design               BEAUTY     NaN
# 126           Skin Care and Natural Beauty               BEAUTY     NaN
# 129    Secrets of beauty, youth and health               BEAUTY     NaN
# ...                                    ...                  ...     ...
# 10824                            Cardio-FR              MEDICAL     NaN
# 10825                   Naruto & Boruto FR               SOCIAL     NaN
# 10831             payermonstationnement.fr  MAPS_AND_NAVIGATION     NaN
# 10835                             FR Forms             BUSINESS     NaN
# 10838               Parkinson Exercices FR              MEDICAL     NaN
#
#       Reviews  Size  Installs  Type Price Content Rating  \
# ...

# %%
playstore.fillna({'Rating':1}, inplace=True)

# %%
playstore[playstore['Rating'].isnull()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
playstore['Type'].unique()
# Out:
# array(['Free', 'Paid', nan], dtype=object)

# %%
playstore['Type'].value_counts()
# Out:
# Type
# Free    10039
# Paid      800
# Name: count, dtype: int64

# %%
playstore.fillna({'Type':'Free'}, inplace=True)

# %%
playstore['Type'].isnull().sum()
# Out:
# 0

# %%
playstore['Android Ver'].value_counts()
# Out:
# Android Ver
# 4.1 and up            2451
# 4.0.3 and up          1501
# 4.0 and up            1375
# Varies with device    1362
# 4.4 and up             980
# 2.3 and up             652
# 5.0 and up             601
# 4.2 and up             394
# 2.3.3 and up           281
# 2.2 and up             244
# 4.3 and up             243
# 3.0 and up             241
# 2.1 and up             134
# 1.6 and up             116
# 6.0 and up              60
# 7.0 and up              42
# 3.2 and up              36
# 2.0 and up              32
# 5.1 and up              24
# 1.5 and up              20
# 4.4W and up             12
# 3.1 and up              10
# 2.0.1 and up             7
# 8.0 and up               6
# 7.1 and up               3
# 4.0.3 - 7.1.1            2
# 5.0 - 8.0                2
# 1.0 and up               2
# 7.0 - 7.1.1              1
# 4.1 - 7.1.1              1
# 5.0 - 6.0                1
# 2.2 - 7.1.1              1
# 5.0 - 7.1.1              1
# Name: count, dtype: int64

# %%
playstore[playstore['Android Ver'].isnull()]
# Out:
#                          App         Category  Rating Reviews  Size Installs  \
# 4453  [substratum] Vacuum: P  PERSONALIZATION     4.4     230   11M   1,000+
# 4490    Pi Dark [substratum]  PERSONALIZATION     4.5     189  2.1M  10,000+
#
#       Type  Price Content Rating           Genres    Last Updated Current Ver  \
# 4453  Paid  $1.49       Everyone  Personalization   July 20, 2018         4.4
# 4490  Free      0       Everyone  Personalization  March 27, 2018         1.1
#
#      Android Ver
# 4453         NaN
# 4490         NaN

# %%
playstore[playstore['Category'].str.contains('personalization', case=False)]
# Out:
#                                                    App         Category  \
# 3352                                     Nova Launcher  PERSONALIZATION
# 3353                                   Funny Ringtones  PERSONALIZATION
# 3354                     ZEDGE™ Ringtones & Wallpapers  PERSONALIZATION
# 3355                    XOS - Launcher,Theme,Wallpaper  PERSONALIZATION
# 3356                        3D Live Neon Weed Launcher  PERSONALIZATION
# ...                                                ...              ...
# 10710                                    Stylish Fonts  PERSONALIZATION
# 10722                   Launcher Theme for LG K10 2018  PERSONALIZATION
# 10733                           FP Click sound changer  PERSONALIZATION
# 10747                             FP Charging Daydream  PERSONALIZATION
# 10788  Fountain Live Wallpaper HD – Dubai Wallpaper 3D  PERSONALIZATION
#
#        Rating  Reviews                Size      Installs  Type Price  \
# ...

# %%
playstore['Android Ver'].mode()
# Out:
# 0    4.1 and up
# Name: Android Ver, dtype: object

# %%
android=playstore['Android Ver'].mode()[0]
android
# Out:
# '4.1 and up'

# %%
playstore.fillna({'Android Ver': android}, inplace=True)

# %%
playstore['Android Ver'].isnull().sum()
# Out:
# 0

# %%
playstore['Current Ver'].mode()
# Out:
# 0    Varies with device
# Name: Current Ver, dtype: object

# %%
current=playstore['Current Ver'].mode()[0]
current
# Out:
# 'Varies with device'

# %%
playstore.fillna({'Current Ver': current}, inplace=True)

# %%
playstore['Current Ver'].isnull().sum()
# Out:
# 0

# %%
index_review=playstore[playstore['Reviews']=='0'].index
index_review
# Out:
# Index([  478,   479,   621,   623,   627,   628,   630,   632,   635,   639,
#        ...
#        10734, 10736, 10748, 10762, 10772, 10773, 10774, 10798, 10822, 10835],
#       dtype='int64', length=596)

# %%
# Updating values
playstore.loc[index_review,'Rating']=0

# %%
playstore
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
playstore['Installs'].str.replace(',','').str.replace('+','').str.strip().astype('int64')
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10836        5000
# 10837         100
# 10838        1000
# 10839        1000
# 10840    10000000
# Name: Installs, Length: 10840, dtype: int64

# %%
playstore['Installs']=playstore['Installs'].str.replace(',','').str.replace('+','').str.strip().astype('int64')

# %%
playstore['Installs']
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10836        5000
# 10837         100
# 10838        1000
# 10839        1000
# 10840    10000000
# Name: Installs, Length: 10840, dtype: int64

# %%
playstore['Price'].value_counts()
# Out:
# Price
# 0         10040
# $0.99       148
# $2.99       129
# $1.99        73
# $4.99        72
#           ...
# $19.90        1
# $1.75         1
# $14.00        1
# $4.85         1
# $1.04         1
# Name: count, Length: 92, dtype: int64

# %%
playstore['Price']=playstore['Price'].str.replace('$','').str.strip().astype('float64')

# %%
playstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          10840 non-null  float64
#  3   Reviews         10840 non-null  object
#  4   Size            10840 non-null  object
#  5   Installs        10840 non-null  int64
#  6   Type            10840 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10840 non-null  object
#  12  Android Ver     10840 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1.4+ MB

# %%
playstore['Reviews'].value_counts()
# Out:
# Reviews
# 0         596
# 1         272
# 2         214
# 3         175
# 4         137
#          ...
# 4272        1
# 5517        1
# 4057        1
# 459797      1
# 398307      1
# Name: count, Length: 6001, dtype: int64

# %%
playstore[playstore['Reviews'].str.isalpha()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
playstore['Reviews'].astype('int64')
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10836        38
# 10837         4
# 10838         3
# 10839       114
# 10840    398307
# Name: Reviews, Length: 10840, dtype: int64

# %%
playstore['Reviews']=playstore['Reviews'].astype('int64')

# %%
# date conversion using pd.to_datetime()
playstore['Last Updated']=pd.to_datetime(playstore['Last Updated'])

# %%
playstore.duplicated().any()
# Out:
# True

# %%
playstore[playstore.duplicated(keep=False)].sort_values(by='App')
# Out:
#                                                     App            Category  \
# 1393                              10 Best Foods for You  HEALTH_AND_FITNESS
# 1407                              10 Best Foods for You  HEALTH_AND_FITNESS
# 2543                         1800 Contacts - Lens Store             MEDICAL
# 2322                         1800 Contacts - Lens Store             MEDICAL
# 2256                         2017 EMRA Antibiotic Guide             MEDICAL
# ...                                                 ...                 ...
# 3063  theScore: Live Sports Scores, News, Stats & Vi...              SPORTS
# 3055  theScore: Live Sports Scores, News, Stats & Vi...              SPORTS
# 3103                           trivago: Hotels & Travel    TRAVEL_AND_LOCAL
# 3202                           trivago: Hotels & Travel    TRAVEL_AND_LOCAL
# 3118                           trivago: Hotels & Travel    TRAVEL_AND_LOCAL
#
# ...

# %%
playstore.drop_duplicates(inplace=True)

# %%
playstore.duplicated().any()
# Out:
# False

# %%
playstore.describe()
# Out:
#              Rating       Reviews      Installs         Price  \
# count  10357.000000  1.035700e+04  1.035700e+04  10357.000000
# mean       3.679695  4.059046e+05  1.415776e+07      1.030800
# min        0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%        3.700000  3.200000e+01  1.000000e+03      0.000000
# 50%        4.200000  1.680000e+03  1.000000e+05      0.000000
# 75%        4.500000  4.641600e+04  1.000000e+06      0.000000
# max        5.000000  7.815831e+07  1.000000e+09    400.000000
# std        1.354984  2.696778e+06  8.023955e+07     16.278625
#
#                         Last Updated
# count                          10357
# mean   2017-11-14 09:25:19.320266496
# min              2010-05-21 00:00:00
# 25%              2017-09-03 00:00:00
# 50%              2018-05-20 00:00:00
# 75%              2018-07-19 00:00:00
# max              2018-08-08 00:00:00
# std                              NaN

# %%
playstore[400==playstore['Price']]
# Out:
#                            App   Category  Rating  Reviews  Size  Installs  \
# 4367  I'm Rich - Trump Edition  LIFESTYLE     3.6      275  7.3M     10000
#
#       Type  Price Content Rating     Genres Last Updated Current Ver  \
# 4367  Paid  400.0       Everyone  Lifestyle   2018-05-03       1.0.1
#
#      Android Ver
# 4367  4.1 and up

# %%
playstore.reset_index(drop=True)
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10352                                   Sya9a Maroc - FR               FAMILY
# 10353                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10354                             Parkinson Exercices FR              MEDICAL
# 10355                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10356      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
playstore.to_csv('PlayStore_Clean.csv')

# %%
playstore
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
playstore['Content Rating'].value_counts()
# Out:
# Content Rating
# Everyone           8382
# Teen               1146
# Mature 17+          447
# Everyone 10+        377
# Adults only 18+       3
# Unrated               2
# Name: count, dtype: int64
